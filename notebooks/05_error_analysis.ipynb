# %%
import os
import joblib
import pandas as pd

print(os.getcwd())
# Out:
# e:\customer-churn-predictor\notebooks

# %%
df = pd.read_csv("../data/churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
model = joblib.load("../models/churn_model.pkl")

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"].map({"Yes": 1, "No": 0})

# %%
y_pred = model.predict(X)
y_proba = model.predict_proba(X)[:, 1]

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y, y_pred)
print(cm)
# Out:
# [[4997  177]
#  [ 473 1396]]

# %%
tn, fp, fn, tp = cm.ravel()

print("False Negatives:", fn)
# Out:
# False Negatives: 473

# %%
df["pred"] = y_pred

missed = df[(df["Churn"] == "Yes") & (df["pred"] == 0)]
missed.head()
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 18   4190-MFLUW  Female              0     Yes        Yes      10
# 51   9420-LOJKX  Female              0      No         No      15
# 97   0278-YXOOG    Male              0      No         No       5
# 104  3192-NQECA    Male              0     Yes         No      68
# 110  0486-HECZI    Male              0     Yes         No      55
#
#     PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 18           Yes            No             DSL                   No  ...
# 51           Yes            No     Fiber optic                  Yes  ...
# 97           Yes            No              No  No internet service  ...
# 104          Yes           Yes     Fiber optic                   No  ...
# 110          Yes           Yes     Fiber optic                  Yes  ...
#
#              TechSupport          StreamingTV      StreamingMovies  \
# 18                   Yes                   No                   No
# 51                    No                  Yes                  Yes
# 97   No internet service  No internet service  No internet service
# 104                  Yes                  Yes                  Yes
# 110                   No                  Yes                   No
#
#            Contract PaperlessBilling              PaymentMethod  \
# 18   Month-to-month               No    Credit card (automatic)
# 51   Month-to-month              Yes    Credit card (automatic)
# 97   Month-to-month               No               Mailed check
# 104        Two year              Yes  Bank transfer (automatic)
# 110  Month-to-month              Yes           Electronic check
#
#     MonthlyCharges TotalCharges  Churn pred
# 18           55.20       528.35    Yes    0
# 51           99.10       1426.4    Yes    0
# 97           21.05       113.85    Yes    0
# 104         110.00      7611.85    Yes    0
# 110          96.75       5238.9    Yes    0
#
# [5 rows x 22 columns]

# %% [markdown]
# Model tends to miss high-risk long-tenure customers.
